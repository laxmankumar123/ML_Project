# %% [markdown]
# # How to connect DB with jupyter notebook

# %%
import pymysql
import pandas as pd

# connect to MySQL
conn = pymysql.connect(
    host="localhost",
    user="root",           # your MySQL username
    password="",  # your MySQL password
    database="Interview_Qs"     # the DB where students1 exists
)

# run query and fetch data
df = pd.read_sql("SELECT * FROM students1;", conn)
df = pd.read_sql("SELECT * FROM departments1;", conn)
# Out:
# /var/folders/0_/_j79x_dj05zd163rrc4lm07h0000gn/T/ipykernel_51285/44934475.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM students1;", conn)
# /var/folders/0_/_j79x_dj05zd163rrc4lm07h0000gn/T/ipykernel_51285/44934475.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM departments1;", conn)

# %%
import pandas as pd
from sqlalchemy import create_engine

# create engine with pymysql
engine = create_engine("mysql+pymysql://root:@localhost/Interview_Qs")

# fetch tables
students1 = pd.read_sql("SELECT * FROM students1;", engine)
departments1 = pd.read_sql("SELECT * FROM departments1;", engine)
marks1 = pd.read_sql("select * from marks;", engine)

result = pd.read_sql("select * from marks;", engine)


print("Students:")
print(students1.head())

print("\nDepartments:")
print(departments1.head())


print(students1.to_string(index=False))
print("")
print("")
print(departments1.to_string(index=False))
print("")
print("")
print(marks1.to_string(index=False))
# Out:
# Students:
#    student_id  student_name  dept_id  year_of_study
# 0           1  Laxman Kumar        1              4
# 1           2   Priya Verma        1              3
# 2           3   Sahil Yadav        1              2
# 3           4  Rohit Sharma        2              4
# 4           5  Aditya Patel        2              2
#
# Departments:
#    dept_id               dept_name
# 0        1        Computer Science
# 1        2  Electrical Engineering
# 2        3  Mechanical Engineering
#  student_id student_name  dept_id  year_of_study
#           1 Laxman Kumar        1              4
#           2  Priya Verma        1              3
#           3  Sahil Yadav        1              2
#           4 Rohit Sharma        2              4
#           5 Aditya Patel        2              2
#           6  Ankit Singh        2              3
#           7   Neha Gupta        1              1
#           8  Rahul Mehra        3              3
# ...

# %% [markdown]
# # image show

# %%
k

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Read image
img = mpimg.imread("moon.jpg")
img1 = mpimg.imread("Chittorgrah.jpg")
# Show image
plt.imshow(img)
plt.imshow(img1)
# plt.axis("off")  # hide axis
plt.show()

# %% [markdown]
# # Read Excal file

# %%
import pandas as pd
# Replace 'data.xlsx' with your file path
df = pd.read_excel("Financial Sample.xlsx")

# Show first 5 rows
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
# df = pd.read_excel("Financial Sample.xlsx", sheet_name="Sheet1")
xls = pd.ExcelFile("Financial Sample.xlsx")
print(xls.sheet_names)
# Out:
# ['Sheet1']

# %%
# Check columns
df.columns

# Check data shape
df.shape

# Summary statistics
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.427859           108.602612  136.775515  2.542623e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       800.320000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure and axis
fig, ax = plt.subplots()

# Draw a rectangle: Rectangle((x, y), width, height)
rect = patches.Rectangle((0.5, 0.5), 12, 3, linewidth=2, edgecolor='red', facecolor='blue', alpha=0.3)
ax.add_patch(rect)

# Set limits to see the rectangle
ax.set_xlim(0, 18)
ax.set_ylim(0, 4)

plt.show()

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_x86_64.whl.metadata (19 kB)
# ...
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_x86_64.whl (57.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 1.1 MB/s  0:00:19m0:00:0100:01m
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled numpy-2.3.3━━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]0m [opencv-python]
# ...

# %%
import cv2
from matplotlib import pyplot as plt

# Load an image
img = cv2.imread('moon.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Draw rectangle: (image, top-left, bottom-right, colour (BGR), thickness)
cv2.rectangle(img, (30, 30), (500, 150), (255, 0, 0), 3)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from IPython.display import display, SVG

display(SVG('<svg height="100" width="200">'
            '<rect width="200" height="100" style="fill:blue;stroke:red;stroke-width:3;" />'
            '</svg>'))

# %%
print("ML Project")
# Out:
# ML Project
